# %% [markdown]
# ### Import Modules

# %%
import boto3
import spotipy
import spotipy.util as util
import os
from json.decoder import JSONDecodeError
import spotipy
import requests
from spotipy import util
import time
import spotipy
import spotipy.util as util
import matplotlib
from sklearn.manifold import TSNE
import spotipy
import spotipy.oauth2 as oauth2
import json
from PIL import Image, ImageFilter
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import pandas as pd
from PIL import Image
import numpy as np
import boto3
import urllib
import json
from nltk.corpus import stopwords
import gensim
from pymongo import MongoClient
from gensim.scripts.glove2word2vec import glove2word2vec
from gensim.models import KeyedVectors
from sklearn.preprocessing import MinMaxScaler
from gensim.test.utils import datapath, get_tmpfile
import pickle
import scipy
import datetime
pd.set_option('display.max_columns', 500)

# %matplotlib inline

# %% [markdown]
# ### Phease 1:
# Take User input image and save it to S3

# %%
aws_access_key_id='AKIAIER77XWYHTNMKAPA'
aws_secret_access_key= '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'

s3 = boto3.resource(
    's3',
    region_name='us-east-2',
    aws_access_key_id=aws_access_key_id,
    aws_secret_access_key=aws_secret_access_key,
)

# %%
# List Bucket Names
for bucket in s3.buckets.all():
    print(bucket.name)
# Out:
# bucketforpackages
# cf-templates-mtre1eej2jle-us-east-1
# cf-templates-mtre1eej2jle-us-east-2
# deeplens-sagemaker-bba7d7fb-df61-439a-8f97-7d0332aec452
# elasticbeanstalk-us-east-1-338531412026
# elasticbeanstalk-us-east-2-338531412026
# facialanalysistest
# lkljll
# metisvideo
# mybucket-test-1
# mybucket-test-2
# trylast222
# us-east-11

# %% [markdown]
# #### Declare Variable for Photo Name
# - Use Timestamp for uploaded image name

# %%
# photo_title='file03_test.jpg'
photo_title=datetime.datetime.now().strftime("%Y%m%d_%H%M%S")+'.jpg'
photo_title
# Out:
# '20180703_233219.jpg'

# %%
#Save Photo Locally. 
resource = urllib.request.urlopen("https://thumbor.forbes.com/thumbor/960x0/https%3A%2F%2Fblogs-images.forbes.com%2Ftravisbradberry%2Ffiles%2F2014%2F10%2FToxic_people1.jpg")
output = open(f"images/{photo_title}","wb")
output.write(resource.read())
output.close()

# %% [markdown]
# #### Upload Photo to S3

# %%
data = open(f'images/{photo_title}', 'rb')
s3.Bucket('facialanalysistest').put_object(Key=f'{photo_title}', Body=data, ACL='public-read')
# Out:
# s3.Object(bucket_name='facialanalysistest', key='20180703_233219.jpg')

# %% [markdown]
# #### Create a between S3 and AWS Rek Interface

# %%
photo=photo_title
bucket='facialanalysistest'
client=boto3.client('rekognition', region_name='us-east-2',    aws_access_key_id=aws_access_key_id, aws_secret_access_key=aws_secret_access_key,)

response = client.detect_faces(Image={'S3Object':{'Bucket':bucket,'Name':photo}},Attributes=['ALL'])

# %%
#Capture rekognition response: 
face_details_imported=response

# %% [markdown]
# ###### Visualize Data Recieved from Rekognition interface

# %%
print(f'number of people: {len(response["FaceDetails"])}')  #number of peopple. 
response['FaceDetails'][0]['Emotions']  # Emotion of person
# Out:
# number of people: 2
# [{'Confidence': 50.27027893066406, 'Type': 'HAPPY'},
#  {'Confidence': 33.81645584106445, 'Type': 'SAD'},
#  {'Confidence': 9.769832611083984, 'Type': 'CONFUSED'}]

# %% [markdown]
# ### Phease 2: Save Image feature Data on MongoDB

# %%
client = MongoClient()
db = client.facial_features
db.collection_names()
# Out:
# ['dict_collection']

# %% [markdown]
# #### Insert AWS Rek Dicto Into Mongo

# %%
db.dict_collection.insert({'id':photo_title, "details":face_details_imported})
# Out:
# /Users/honeybadger4/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   """Entry point for launching an IPython kernel.
# ObjectId('5b3c3ffe36a8221184f92200')

# %% [markdown]
# #### Call Mongo Entry  (Finds the phto in the ID using the saved photo tag)

# %%
#list all people from 1 photo
dict_imported_mongo=list(db.dict_collection.find({'id':photo_title}))[0]  #<-- 0 is eval and selects first of all duplicates. 
list(db.dict_collection.find({'id':photo_title}))[0]['details']['FaceDetails'][0]['Emotions'] #<-- 0 index the person.
# Out:
# [{'Confidence': 50.27027893066406, 'Type': 'HAPPY'},
#  {'Confidence': 33.81645584106445, 'Type': 'SAD'},
#  {'Confidence': 9.769832611083984, 'Type': 'CONFUSED'}]

# %%
list(db.dict_collection.find({'id':photo_title}))[0] ['details']['FaceDetails'][0]['Emotions'] #<-- 0 index the person.
# Out:
# [{'Confidence': 50.27027893066406, 'Type': 'HAPPY'},
#  {'Confidence': 33.81645584106445, 'Type': 'SAD'},
#  {'Confidence': 9.769832611083984, 'Type': 'CONFUSED'}]

# %% [markdown]
# #### Plot emotions onto the image
# -Using Extract_Emotions Feature.
# -Data is collected from Mongo

# %%
def extract_emotions(dict_mongo,photo):
    coords_x_m=[]
    coords_y_m=[]
    emotion_plot_v1_m=[]
    emotion_plot_v2_m=[]
    emotion_plot_v3_m=[]
    num_of_people_m=len(dict_mongo['details']['FaceDetails'])

    for i in range(num_of_people_m):
        coords_x_m.append((dict_mongo)['details']['FaceDetails'][i][ 'Landmarks'][3]['X'])
        coords_y_m.append((dict_mongo)['details']['FaceDetails'][i][ 'Landmarks'][3]['Y'])
        
        emotion_type_v1_m=(dict_mongo)['details']['FaceDetails'][i]['Emotions'][0]['Type']
        emotion_conf_v1_m=round((dict_mongo)['details']['FaceDetails'][i]['Emotions'][0]['Confidence'],2)
        emotion_v1_m=str(emotion_type_v1_m)+' '+str(emotion_conf_v1_m)+"%"
        emotion_plot_v1_m.append(emotion_v1_m)

        emotion_type_v2_m=(dict_mongo)['details']['FaceDetails'][i]['Emotions'][1]['Type']
        emotion_conf_v2_m=round(dict_mongo['details']['FaceDetails'][i]['Emotions'][1]['Confidence'],2)
        emotion_v2_m=str(emotion_type_v2_m)+' '+str(emotion_conf_v2_m)+"%"
        emotion_plot_v2_m.append(emotion_v2_m)

        emotion_type_v3_m=(dict_mongo)['details']['FaceDetails'][i]['Emotions'][2]['Type']
        emotion_conf_v3_m=round(dict_mongo['details']['FaceDetails'][i]['Emotions'][2]['Confidence'],2)
        emotion_v3_m=str(emotion_type_v3_m)+' '+str(emotion_conf_v3_m)+"%"
        emotion_plot_v3_m.append(emotion_v3_m)
        
    emotion_plot_v1_m=[w.replace('CALM', 'calm') for w in emotion_plot_v1_m]
    im = np.array(Image.open(f'images/{photo}'), dtype=np.uint8)
    len2=(im.shape[0])
    width2=im.shape[1]
    print(len2,width2)
    plt.rcParams.update({'font.size': 12})
    # Create figure and axes Adjust size all kinds
    fig,ax = plt.subplots(1,figsize=(10, 10))
    
    for i in range(num_of_people_m):
    # Create a Rectangle patch
        rect = patches.Rectangle((coords_x_m[i]*width2-width2,coords_y_m[i]*len2-len2*.06),50,50,linewidth=1,edgecolor='yellow',facecolor='none')
        # Add the patch to the Axes
        ax.add_patch(rect)
        plt.text(coords_x_m[i]*width2-width2*.03,coords_y_m[i]*len2-len2*.085, emotion_plot_v1_m[i],color='yellow')
        plt.text(coords_x_m[i]*width2-width2*.03,coords_y_m[i]*len2-len2*.070, emotion_plot_v2_m[i],color='cyan')
        plt.text(coords_x_m[i]*width2-width2*.03,coords_y_m[i]*len2-len2*.055, emotion_plot_v3_m[i],color='white')
    ax.imshow(im)
    
extract_emotions(dict_imported_mongo,photo_title)
# Out:
# 653 960

# %% [markdown]
# ### Phase 3: Average and Scale Emotions for a given Picture

# %%
client = MongoClient()
db = client.facial_features
db.collection_names()
dict_emotion_values_list_test=list(db.dict_collection.find({'id':photo_title}))[0]

# %% [markdown]
# ##### Import Data from Mongo

# %%
dict_all_people_emo=[]
for i in range(len(dict_emotion_values_list_test['details']['FaceDetails'])):
    dict_all_people_emo.append(dict_emotion_values_list_test['details']['FaceDetails'][i]['Emotions'])
    
print(f'number of people: {len((dict_all_people_emo))}')
# Out:
# number of people: 2

# %% [markdown]
# #### Average emotion data for 8 Emotions

# %%
dict_emotion_values_v2={'happy':0, 'sad':0, 'angry':.0, 'confused':0, 'surprised':0, 'calm':0, 'unknown':0,'disgusted':0}

for j in (dict_all_people_emo):
    for i in range(len(j)):
        dict_emotion_values_v2[j[i]['Type'].lower()]+=j[i]['Confidence']
# dict_emotion_values_v2['happy']=dict_emotion_values_v2['happy']*.2
dict_emotion_values_v2.values()
dict_emotion_values_list=np.array(list(dict_emotion_values_v2.values())).reshape(-1,1)
pd.DataFrame(dict_emotion_values_list )

#Scale the appened dictionary. 
scaler=MinMaxScaler()
X_train_minmax = scaler.fit_transform(dict_emotion_values_list)
# X_train_minmax=[1-i for i in X_train_minmax]
print("Average Array for all emotions")
X_train_minmax
# Out:
# Average Array for all emotions
# array([[ 1.        ],
#        [ 0.49828211],
#        [ 0.67530214],
#        [ 0.14395751],
#        [ 0.10858323],
#        [ 0.        ],
#        [ 0.        ],
#        [ 0.        ]])

# %% [markdown]
# ### Phase 4: Lyrics Analysis using Word2Vec

# %%
# Import 1.2 Million words in 100D Vector Space
stoplist = stopwords.words('english')
glove_file2 = datapath('/home/ubuntu/downloads/glove/glove.twitter.27B.100d.txt')
tmp_file2 = get_tmpfile("glove_word2vec2.txt")
glove2word2vec(glove_file2, tmp_file2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-69cf3daad3d8> in <module>()
#       3 glove_file2 = datapath('/home/ubuntu/downloads/glove/glove.twitter.27B.100d.txt')
#       4 tmp_file2 = get_tmpfile("glove_word2vec2.txt")
# ----> 5 glove2word2vec(glove_file2, tmp_file2)
#
# ~/anaconda3/lib/python3.6/site-packages/gensim/scripts/glove2word2vec.py in glove2word2vec(glove_input_file, word2vec_output_file)
#     102
#     103     """
# --> 104     num_lines, num_dims = get_glove_info(glove_input_file)
#     105     logger.info("converting %i vectors from %s to %s", num_lines, glove_input_file, word2vec_output_file)
#     106     with smart_open(word2vec_output_file, 'wb') as fout:
#
# ~/anaconda3/lib/python3.6/site-packages/gensim/scripts/glove2word2vec.py in get_glove_info(glove_file_name)
#      79
#      80     """
# ---> 81     with smart_open(glove_file_name) as f:
#      82         num_lines = sum(1 for _ in f)
#      83     with smart_open(glove_file_name) as f:
#
# ~/anaconda3/lib/python3.6/site-packages/smart_open/smart_open_lib.py in smart_open(uri, mode, **kw)
#     174             encoding = kw.pop('encoding', None)
#     175             errors = kw.pop('errors', DEFAULT_ERRORS)
# --> 176             return file_smart_open(parsed_uri.uri_path, mode, encoding=encoding, errors=errors)
#     177         elif parsed_uri.scheme in ("s3", "s3n", 's3u'):
#     178             return s3_open_uri(parsed_uri, mode, **kw)
#
# ~/anaconda3/lib/python3.6/site-packages/smart_open/smart_open_lib.py in file_smart_open(fname, mode, encoding, errors)
#     669     except KeyError:
#     670         raw_mode = mode
# --> 671     raw_fobj = open(fname, raw_mode)
#     672     decompressed_fobj = compression_wrapper(raw_fobj, fname, raw_mode)
#     673     decoded_fobj = encoding_wrapper(decompressed_fobj, mode, encoding=encoding, errors=errors)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/ubuntu/downloads/glove/glove.twitter.27B.100d.txt'

# %% [markdown]
# #### Create the Word2Vec Model
# -Average Execute time (1Min)

# %%
model3 = KeyedVectors.load_word2vec_format(tmp_file2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-e0769d34f002> in <module>()
# ----> 1 model3 = KeyedVectors.load_word2vec_format(tmp_file2)
#
# ~/miniconda3/lib/python3.6/site-packages/gensim/models/keyedvectors.py in load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype)
#    1117         return _load_word2vec_format(
#    1118             Word2VecKeyedVectors, fname, fvocab=fvocab, binary=binary, encoding=encoding, unicode_errors=unicode_errors,
# -> 1119             limit=limit, datatype=datatype)
#    1120
#    1121     def get_keras_embedding(self, train_embeddings=False):
#
# ~/miniconda3/lib/python3.6/site-packages/gensim/models/utils_any2vec.py in _load_word2vec_format(cls, fname, fvocab, binary, encoding, unicode_errors, limit, datatype)
#     222                 if len(parts) != vector_size + 1:
#     223                     raise ValueError("invalid vector on line %s (is this really the text format?)" % line_no)
# --> 224                 word, weights = parts[0], [datatype(x) for x in parts[1:]]
#     225                 add_word(word, weights)
#     226     if result.vectors.shape[0] != len(result.vocab):
#
# ~/miniconda3/lib/python3.6/site-packages/gensim/models/utils_any2vec.py in <listcomp>(.0)
#     222                 if len(parts) != vector_size + 1:
#     223                     raise ValueError("invalid vector on line %s (is this really the text format?)" % line_no)
# --> 224                 word, weights = parts[0], [datatype(x) for x in parts[1:]]
#     225                 add_word(word, weights)
#     226     if result.vectors.shape[0] != len(result.vocab):
#
# KeyboardInterrupt:

# %% [markdown]
# ###### Test the word2vec model

# %%
model3.similar_by_word('happy' , topn=5)
# Out:
# [('birthday', 0.9259342551231384),
#  ('day', 0.8549739718437195),
#  ('bday', 0.8145427703857422),
#  ('merry', 0.7886534333229065),
#  ('love', 0.7855905294418335)]

# %% [markdown]
# ### Phase 5, Assign Song Distances to each Emotion using Word2Vec Model

# %%
mood_list=["HAPPY", "SAD", "ANGRY", "CONFUSED", "SURPRISED", "CALM", "UNKNOWN","DISGUSTED"]
mood_list_v2=[i.lower() for i in mood_list]

# %% [markdown]
# #### Import Scraped Songs (From a Pickle) -
# -Data Stored on a Public FTP Server / Hardcoded the link

# %%
import urllib.request
url2 = 'http://downloadforpc.net/Metis/facial_rec/df_export_final.pkl'
response2 = urllib.request.urlopen(url2)
response2

# %%
#Import Scraped Songs
# with open("Lyrics_Folder/df_export_final.pkl",'rb') as picklefile:
#     df3=pickle.load(picklefile)
# print(len((df3)))
# df3.head(1)

df3=pickle.load(response2)

# %% [markdown]
# ##### Create song vectors for each song for each mood
# - Use the function

# %%
def create_song_vector(song):
    """Returns list of moods in percent, an array of 8 items (values 0-1)"""
    list_of_words = str(song).split(" ")
    dim_array_28b = []
    list_mood = []
    list_mood_percent = []
    mood_list_v2 = [
        'happy', 'sad', 'angry', 'confused', 'surprised', 'calm', 'unknown',
        'disgusted']
    for i in range(len(list_of_words)):
        try:
            dim_array_28b.append(model3[list_of_words[i]])
        except:
            pass
    song_vector = (np.average(dim_array_28b, axis=0))
    for i in range(len(mood_list_v2)):
        mood_list_v2.append(mood_list_v2[i])
        list_mood_percent.append(
            scipy.spatial.distance.cosine(song_vector,
                                          model3[mood_list_v2[i]]))
    return list_mood_percent



def song_100D_vector(song):
    """Returns 100D Song Vector"""
    list_of_words = str(song).split(" ")
    dim_array_28b = []
    list_mood = []
    list_mood_percent = []
    mood_list_v2 = [
        'happy', 'sad', 'angry', 'confused', 'surprised', 'calm', 'unknown',
        'disgusted']
    for i in range(len(list_of_words)):
        try:
            dim_array_28b.append(model3[list_of_words[i]])
        except:
            pass
    song_vector = (np.average(dim_array_28b, axis=0))
    return song_vector

# %% [markdown]
# ###### Test Create_song_vector

# %%
song_100D_vector(df3.lyrics[2])
str(df3.lyrics[2])
song_vector2=create_song_vector(df3.lyrics[0])
song_vector2
# Out:
# [0.3200199007987976,
#  0.2563716173171997,
#  0.36654365062713623,
#  0.32330256700515747,
#  0.2699214220046997,
#  0.3210229277610779,
#  0.5147216618061066,
#  0.6552886366844177]

# %% [markdown]
# ##### Use Apply the function to add new columns using the custom functions:
# (1/2) Adding Distance column for each song and spread columns out for each word vector
#
# Execute Time:5m 40s

# %%
dataframe_dist_added=df3.copy()
dataframe_dist_added.head(1)
dataframe_dist_added["dist_col"]=dataframe_dist_added.lyrics.apply(create_song_vector)
dataframe_dist_added["song_100D_vector"]=dataframe_dist_added.lyrics.apply(song_100D_vector)
dataframe_dist_added[mood_list_v2] = pd.DataFrame(dataframe_dist_added.dist_col.values.tolist(), index= dataframe_dist_added.index)
dataframe_dist_added
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-d78f222714f6> in <module>()
# ----> 1 dataframe_dist_added=df3.copy()
#       2 dataframe_dist_added.head(1)
#       3 dataframe_dist_added["dist_col"]=dataframe_dist_added.lyrics.apply(create_song_vector)
#       4 # dataframe_dist_added["song_100D_vector"]=dataframe_dist_added.lyrics.apply(song_100D_vector)
#       5 dataframe_dist_added[mood_list_v2] = pd.DataFrame(dataframe_dist_added.dist_col.values.tolist(), index= dataframe_dist_added.index)
#
# NameError: name 'df3' is not defined

# %% [markdown]
# #### Apply the function: add new column song feature distance.
# (2/2) Adding song feature column for each song

# %%
zip_values=list(zip(dataframe_dist_added['danceability'],dataframe_dist_added['acousticness'],dataframe_dist_added['energy']))

# %%
dataframe_dist_added['emotionmatrix']=zip_values
dataframe_dist_added['emotionmatrix']=dataframe_dist_added['emotionmatrix'].apply(list)
dataframe_dist_added.head(1)  # This object exists in pickle
# Out:
#    level_0                    name         artist_x  \
# 0        0  all i could do was cry  beyonce knowles
#
#                                             album  explicit  danceability  \
# 0  Music From The Motion Picture Cadillac Records     False         0.372
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.488    9    -9.471     1        0.072         0.358          0.000706
#
#    liveness  valence    tempo            type                      id  \
# 0     0.104      0.5  185.262  audio_features  35g7hIs8Jf8tvXPRMSkNPC
#
#                                     uri  \
# 0  spotify:track:35g7hIs8Jf8tvXPRMSkNPC
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/35g7hIs8Jf8t...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/35g7...       190400
#
#    time_signature                                   primary_key  index  \
# 0               3  (beyonce knowles, all i could do was cry, 5)      5
#
#                      song  year         artist_y genre  \
# 0  all i could do was cry  2009  beyonce knowles   Pop
#
#                                               lyrics  \
# 0  I heard Church bells ringing I heard A choir s...
#
#                                         tup_col  \
# 0  (beyonce knowles, all i could do was cry, 5)
#
#                                             dist_col  \
# 0  [0.3200199007987976, 0.2563716173171997, 0.366...
#
#                                     song_100D_vector    happy       sad  \
# 0  [0.03022172, 0.25325352, 0.13928455, 0.0949978...  0.32002  0.256372
#
#       angry  confused  surprised      calm   unknown  disgusted  \
# 0  0.366544  0.323303   0.269921  0.321023  0.514722   0.655289
#
#            emotionmatrix
# 0  [0.372, 0.358, 0.488]

# %% [markdown]
# ### Phase 4-5  (Import)
# -No need to run Phase 4-5, encompossed in file below:
# -Data Stored on a Public FTP Server / Hardcoded the link

# %%
import urllib.request
url = 'http://downloadforpc.net/Metis/facial_rec/df_export_TSNE.pkl'
response = urllib.request.urlopen(url)
response

# %%
dataframe_dist_added=pickle.load(response)

# %%
print(len(dataframe_dist_added.columns))
(len(dataframe_dist_added))

# %% [markdown]
# #### Declare two additonal functions to calculate distance per song (X_train_minmax) input3(implicit)

# %%
def song_dist(dataframe_dist_added):
#     song_cosine=scipy.spatial.distance.cosine(dict_emotion_values_list, dataframe_dist_added)
    song_cosine=scipy.spatial.distance.cosine(X_train_minmax, dataframe_dist_added)
    
    return song_cosine
# scipy.spatial.distance.cosine(dict_emotion_values_list, dataframe_dist_added.dist_col[2323])


def feature_dist(dataframe_dist_added):
#     song_cosine=scipy.spatial.distance.cosine(dict_emotion_values_list, dataframe_dist_added)
    song_cosine=scipy.spatial.distance.cosine(X_train_minmax[0:3], dataframe_dist_added)
    
    return song_cosine

# %%
dataframe_dist_added_v2=dataframe_dist_added.copy()
dataframe_dist_added_v2['word_vec_similarity']=dataframe_dist_added_v2.dist_col.apply(song_dist)
dataframe_dist_added_v2['emotionmatrix_dist']=dataframe_dist_added_v2.emotionmatrix.apply(feature_dist)
dataframe_dist_added_v2.head(1)
len(dataframe_dist_added_v2)
# Out:
# 260806

# %% [markdown]
# ### Phase 6:  Final Playlist for the User:
# This will be populated on the APP
#
# low - word_vect_dist is good (close match)
#
# low - emotionmatrix_dist is good (close match)

# %%
# final_playlist=dataframe_dist_added_v2[dataframe_dist_added_v2.artist_x=='diamond rio'].sort_values(by='word_vec_similarity').head(20)
final_playlist=dataframe_dist_added_v2.sort_values(by='word_vec_similarity').head(50)
final_playlist
final_playlist.sort_values(by='emotionmatrix_dist')
# Out:
#         level_0                                    name  \
# 211444    85069                             mahna mahna
# 78223     78223                                    open
# 257382   131007                                 no exit
# 259038   132663                                  tukuza
# 181998    55623                               nukuttaja
# 121924   121924                      the debt collector
# 62706     62706                               elephants
# 79423     79423                 night time intermission
# 221360    94985                         ung entreprenor
# 102727   102727                   le voyage de penelope
# 15906     15906                                     030
# 142281    15906                                     030
# 57667     57667                           marching song
# 210631    84256                             hava nagila
# 101644   101644                                  wotton
# 101953   101953                   possum goes to prague
# 138724    12349                                   fresh
# 12349     12349                                   fresh
# 80374     80374                        little liza jane
# 49137     49137                          gayatri mantra
# 117889   117889                               mesmerize
# 38344     38344                   miracula aeternitatis
# 49841     49841                                  allein
# 207609    81234                       hava nagila twist
# 105466   105466                               soulwound
# 107967   107967                          employee 00765
# 182030    55655                                 ihmemaa
# 119411   119411                    flesh eating disease
# 43919     43919                                no sense
# 197686    71311                    disfigured catacombs
# 60669     60669                       body count anthem
# 181464    55089                      the spine splitter
# 86382     86382                            exploitation
# 88025     88025                                 wardead
# 119414   119414                   parasitic infestation
# 114902   114902                       gestated rabidity
# 216378    90003                                pig pong
# 119374   119374                 colostomy jigsaw puzzle
# 204576    78201                      wake up and change
# 204589    78214       only hypocrisy prohibits legality
# 119387   119387         unclogged and ready for spewage
# 166430    40055      manifestation on verrucose urethra
# 252476   126101                           cauterization
# 197992    71617                            necro voyeur
# 166453    40078                            carnal forge
# 166463    40088                          excreted alive
# 251437   125062  playing around before the party starts
# 5879       5879                                dethrone
# 132254     5879                                dethrone
# 185345    58970                          quid sum miser
#
#                        artist_x  \
# 211444                     cake
# 78223                com truise
# 257382            fates warning
# 259038            gloria muliro
# 181998                 apulanta
# 121924                     blur
# 62706              adrian belew
# 79423      charlotte gainsbourg
# 221360                    gilli
# 102727                      air
# 15906                 foxx john
# 142281                foxx john
# 57667                       gob
# 210631           ben folds five
# 101644  circle of dead children
# 101953         blackmores night
# 138724                daft punk
# 12349                 daft punk
# 80374             alison krauss
# 49137               deva premal
# 117889             cindergarden
# 38344          cirque du soleil
# 49841                eric prydz
# 207609              brave combo
# 105466             fear factory
# 107967             blue meanies
# 182030                 apulanta
# 119411      cattle decapitation
# 43919                      fate
# 197686                 disgorge
# 60669                body count
# 181464          cannibal corpse
# 86382                      doom
# 88025                 dismember
# 119414      cattle decapitation
# 114902                  aborted
# 216378        corpsefucking art
# 119374      cattle decapitation
# 204576                  exit 13
# 204589                  exit 13
# 119387      cattle decapitation
# 166430                  carcass
# 252476               dark angel
# 197992                  exhumed
# 166453                  carcass
# 166463                  carcass
# 251437         childish gambino
# 5879                     gadget
# 132254                   gadget
# 185345           andrea bocelli
#
#                                                     album  explicit  \
# 211444                               b-sides and rarities     False
# 78223                                            In Decay     False
# 257382                                            No Exit     False
# 259038                                            Sitolia     False
# 181998                                        Viivakoodit     False
# 121924                                           Parklife     False
# 62706                                            Side One     False
# 79423                                                5:55     False
# 221360                                          Ækte Vare     False
# 102727                                        Moon Safari     False
# 15906                                    Metamatic...Plus     False
# 142281                                   Metamatic...Plus     False
# 57667                              Too Late... No Friends      True
# 210631                         Vault Volume I (1992-1997)     False
# 101644                                 Exotic Sense Decay     False
# 197686  https://api.spotify.com/v1/audio-analysis/2PbL...       157120
# 60669   https://api.spotify.com/v1/audio-analysis/4aVu...       166400
# 181464  https://api.spotify.com/v1/audio-analysis/0rCU...       189267
# 86382   https://api.spotify.com/v1/audio-analysis/4LlM...       102880
# 88025   https://api.spotify.com/v1/audio-analysis/7mGA...       146360
# 119414  https://api.spotify.com/v1/audio-analysis/5BVx...        41480
# 114902  https://api.spotify.com/v1/audio-analysis/1xXm...       244653
# 216378  https://api.spotify.com/v1/audio-analysis/0jLF...        64853
# 119374  https://api.spotify.com/v1/audio-analysis/009g...        35227
# 204576  https://api.spotify.com/v1/audio-analysis/7AkX...       242467
# 204589  https://api.spotify.com/v1/audio-analysis/4Kon...       152333
# 119387  https://api.spotify.com/v1/audio-analysis/7HuY...        35213
# 166430  https://api.spotify.com/v1/audio-analysis/36fv...        61733
# 252476  https://api.spotify.com/v1/audio-analysis/71s1...       438240
# 197992  https://api.spotify.com/v1/audio-analysis/55Iq...       154307
# 166453  https://api.spotify.com/v1/audio-analysis/3wZ8...       234933
# 166463  https://api.spotify.com/v1/audio-analysis/5XeX...        82464
# 251437  https://api.spotify.com/v1/audio-analysis/2DxK...        54453
# 5879    https://api.spotify.com/v1/audio-analysis/0Odm...        58973
# 132254  https://api.spotify.com/v1/audio-analysis/0Odm...        58973
# 185345  https://api.spotify.com/v1/audio-analysis/7zJB...       235693
#
#         time_signature                                        primary_key  \
# 211444               4                        (cake, mahna mahna, 282527)
# 78223                4                         (com truise, open, 122957)
# 257382               4                   (fates warning, no exit, 356564)
# 259038               4                    (gloria muliro, tukuza, 359306)
# 181998               4                      (apulanta, nukuttaja, 235767)
# 121924               3                 (blur, the debt collector, 192306)
# 62706                4                   (adrian belew, elephants, 97492)
# 79423                4  (charlotte gainsbourg, night time intermission...
# 221360               4                   (gilli, ung entreprenor, 297907)
# 102727               4               (air, le voyage de penelope, 162179)
# 15906                4                            (foxx john, 030, 24804)
# 142281               4                            (foxx john, 030, 24804)
# 57667                4                        (gob, marching song, 89907)
# 210631               4              (ben folds five, hava nagila, 281181)
# 101644               4          (circle of dead children, wotton, 160603)
# 101953               4  (blackmores night, possum goes to prague, 161070)
# 138724               4                          (daft punk, fresh, 19283)
# 12349                4                          (daft punk, fresh, 19283)
# 80374                4          (alison krauss, little liza jane, 126671)
# 49137                1               (deva premal, gayatri mantra, 76776)
# 117889               4                  (cindergarden, mesmerize, 186153)
# 38344                4   (cirque du soleil, miracula aeternitatis, 59382)
# 49841                4                        (eric prydz, allein, 77817)
# 207609               4           (brave combo, hava nagila twist, 276483)
# 105466               4                  (fear factory, soulwound, 166832)
# 107967               4             (blue meanies, employee 00765, 170536)
# 182030               4                        (apulanta, ihmemaa, 235806)
# 119411               4  (cattle decapitation, flesh eating disease, 18...
# 43919                4                            (fate, no sense, 68606)
# 197686               4           (disgorge, disfigured catacombs, 261043)
# 60669                4             (body count, body count anthem, 94428)
# 181464               4      (cannibal corpse, the spine splitter, 234965)
# 86382                4                       (doom, exploitation, 135574)
# 88025                4                       (dismember, wardead, 138474)
# 204576                        lyrics highly unnecessary
# 204589  Only hypocrisy prohibits legality  A huge prop...
# 119387  Virus like influenzae invade complete lymph sy...
# 166430  Bloody hypertrophy of papillae spewing urethri...
# 252476                                      instrumental
# 197992   musick   lyrixxx   Ross Sewage        Observi...
# 166453  Multifarious carnage Meretriciously internecin...
# 166463  Eaten aliveMunched into pulp Premature necrops...
# 251437                                 Piano composition
# 5879                                     Dethrone mankind
# 132254                                   Dethrone mankind
# 185345  REQUIEM Quid sum miser tunc dicturus  Quem par...
#
#                                                   tup_col  \
# 211444                        (cake, mahna mahna, 282527)
# 78223                          (com truise, open, 122957)
# 257382                   (fates warning, no exit, 356564)
# 259038                    (gloria muliro, tukuza, 359306)
# 181998                      (apulanta, nukuttaja, 235767)
# 121924                 (blur, the debt collector, 192306)
# 62706                    (adrian belew, elephants, 97492)
# 79423   (charlotte gainsbourg, night time intermission...
# 221360                   (gilli, ung entreprenor, 297907)
# 102727               (air, le voyage de penelope, 162179)
# 15906                             (foxx john, 030, 24804)
# 142281                            (foxx john, 030, 24804)
# 57667                         (gob, marching song, 89907)
# 210631              (ben folds five, hava nagila, 281181)
# 101644          (circle of dead children, wotton, 160603)
# 101953  (blackmores night, possum goes to prague, 161070)
# 138724                          (daft punk, fresh, 19283)
# 12349                           (daft punk, fresh, 19283)
# 80374           (alison krauss, little liza jane, 126671)
# 49137                (deva premal, gayatri mantra, 76776)
# 117889                  (cindergarden, mesmerize, 186153)
# 38344    (cirque du soleil, miracula aeternitatis, 59382)
# 49841                         (eric prydz, allein, 77817)
# 207609           (brave combo, hava nagila twist, 276483)
# 105466                  (fear factory, soulwound, 166832)
# 107967             (blue meanies, employee 00765, 170536)
# 182030                        (apulanta, ihmemaa, 235806)
# 119411  (cattle decapitation, flesh eating disease, 18...
# 43919                             (fate, no sense, 68606)
# 197686           (disgorge, disfigured catacombs, 261043)
# 60669              (body count, body count anthem, 94428)
# 181464      (cannibal corpse, the spine splitter, 234965)
# 86382                        (doom, exploitation, 135574)
# 88025                        (dismember, wardead, 138474)
# 119414  (cattle decapitation, parasitic infestation, 1...
# 114902               (aborted, gestated rabidity, 181850)
# 216378              (corpsefucking art, pig pong, 290310)
# 119374  (cattle decapitation, colostomy jigsaw puzzle,...
# 204576              (exit 13, wake up and change, 271662)
# 204589  (exit 13, only hypocrisy prohibits legality, 2...
# 119387  (cattle decapitation, unclogged and ready for ...
# 166430  (carcass, manifestation on verrucose urethra, ...
# 252476                (dark angel, cauterization, 348312)
# 197992                    (exhumed, necro voyeur, 261559)
# 166453                    (carcass, carnal forge, 210953)
# 166463                  (carcass, excreted alive, 210964)
# 251437  (childish gambino, playing around before the p...
# 5879                             (gadget, dethrone, 9355)
# 132254                           (gadget, dethrone, 9355)
# 185345           (andrea bocelli, quid sum miser, 240939)
#
#                                                  dist_col  \
# 211444  [1.2124126702547073, 1.1526248455047607, 1.117...
# 78223   [1.098292924463749, 1.040152557194233, 0.99930...
# 257382  [0.5470938086509705, 0.4040663242340088, 0.418...
# 259038  [1.1072476655244827, 0.9877640753984451, 1.062...
# 105466   [0.521, 0.00608, 0.975]             0.333595            0.180681
# 107967   [0.388, 0.00372, 0.829]             0.335728            0.205248
# 182030  [0.316, 0.000377, 0.812]             0.332888            0.239974
# 119411  [0.357, 3.59e-06, 0.981]             0.298002            0.251960
# 43919   [0.285, 1.32e-06, 0.817]             0.325701            0.259290
# 197686  [0.342, 0.000158, 0.989]             0.326167            0.260732
# 60669   [0.287, 0.000122, 0.869]             0.305060            0.268549
# 181464  [0.325, 0.000145, 0.993]             0.335108            0.270066
# 86382      [0.252, 0.0657, 0.92]             0.292931            0.274170
# 88025   [0.302, 1.02e-05, 0.995]             0.311204            0.282546
# 119414  [0.293, 5.64e-06, 0.998]             0.327507            0.287891
# 114902  [0.272, 6.82e-06, 0.939]             0.296572            0.290022
# 216378    [0.229, 0.0202, 0.867]             0.324828            0.295843
# 119374  [0.259, 7.78e-06, 0.933]             0.293684            0.296678
# 204576   [0.264, 3.75e-06, 0.96]             0.287567            0.298130
# 204589     [0.221, 0.075, 0.968]             0.293178            0.298374
# 119387  [0.235, 3.66e-06, 0.984]             0.332528            0.318940
# 166430    [0.15, 0.00024, 0.669]             0.306300            0.327535
# 252476       [0.206, 0.0, 0.965]             0.337901            0.334207
# 197992   [0.211, 7.65e-06, 0.99]             0.329474            0.334413
# 166453  [0.198, 2.11e-06, 0.997]             0.333779            0.343422
# 166463  [0.141, 5.57e-05, 0.754]             0.300743            0.350708
# 251437      [0.262, 0.995, 0.13]             0.311351            0.375460
# 5879    [0.0897, 7.44e-06, 0.95]             0.324404            0.413005
# 132254  [0.0897, 7.44e-06, 0.95]             0.324404            0.413005
# 185345     [0.15, 0.986, 0.0565]             0.321666            0.478988

# %% [markdown]
# ### Phase 6: Plot the TSNY!

# %%
import re
import pandas as pd
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import *
stemmer = PorterStemmer()
from gensim.models.word2vec import Word2Vec
from sklearn.manifold import TSNE
from sklearn.datasets import fetch_20newsgroups
import re
import matplotlib.pyplot as plt

# Function for TSNY, Get a sample from a large Dataset
def create_array_sample(arr,sample_len):
    """NumPy does not have a default random sample function, so I've created one here"""
    origLen = len(arr)
    newArr = np.random.choice(range(origLen), sample_len, replace=False)       
    return arr[newArr]

# %%
dataframe_dist_added.columns
df_tsny=dataframe_dist_added[['happy', 'sad', 'surprised','calm']]
df_tsny_v2=df_tsny.dropna()
values_col=df_tsny_v2.columns
values_col
emotion_array=np.array(df_tsny_v2[['happy', 'sad', 'surprised','calm']])
emotion_array_token_sample = create_array_sample(emotion_array,2000)  #Declare the number of points on TSNE Plot
len(emotion_array_token_sample)


# Removes any null values in the dataset. 
token_emotion=[]
for i in emotion_array_token_sample:
    try:
        token_emotion.append(i.astype('Float64'))
    except:
        pass
len(token_emotion)
# Out:
# /home/ubuntu/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: Numeric-style type codes are deprecated and will result in an error in the future.
#   from ipykernel import kernelapp as app
# 2000

# %% [markdown]
# ### Create the TSNY Values

# %%
new_values = TSNE(metric='cosine',verbose=2).fit_transform(token_emotion)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 2000 samples in 0.000s...
# [t-SNE] Computed neighbors for 2000 samples in 0.076s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2000
# [t-SNE] Computed conditional probabilities for sample 2000 / 2000
# [t-SNE] Mean sigma: 0.000063
# [t-SNE] Computed conditional probabilities in 1.152s
# [t-SNE] Iteration 50: error = 67.9724350, gradient norm = 0.2335282 (50 iterations in 2.038s)
# [t-SNE] Iteration 100: error = 64.9837189, gradient norm = 0.2303028 (50 iterations in 1.936s)
# [t-SNE] Iteration 150: error = 66.1156006, gradient norm = 0.2097350 (50 iterations in 1.888s)
# [t-SNE] Iteration 200: error = 64.7131805, gradient norm = 0.2049521 (50 iterations in 1.833s)
# [t-SNE] Iteration 250: error = 64.7226410, gradient norm = 0.2202504 (50 iterations in 1.808s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 64.722641
# [t-SNE] Iteration 300: error = 1.3121338, gradient norm = 0.0016657 (50 iterations in 1.818s)
# [t-SNE] Iteration 350: error = 1.1484824, gradient norm = 0.0003962 (50 iterations in 1.723s)
# [t-SNE] Iteration 400: error = 1.0862499, gradient norm = 0.0002423 (50 iterations in 1.740s)
# [t-SNE] Iteration 450: error = 1.0551752, gradient norm = 0.0001751 (50 iterations in 1.800s)
# [t-SNE] Iteration 500: error = 1.0384561, gradient norm = 0.0001392 (50 iterations in 1.819s)
# [t-SNE] Iteration 550: error = 1.0290512, gradient norm = 0.0000964 (50 iterations in 1.834s)
# [t-SNE] Iteration 600: error = 1.0222510, gradient norm = 0.0000920 (50 iterations in 1.853s)
# [t-SNE] Iteration 650: error = 1.0171671, gradient norm = 0.0000783 (50 iterations in 1.843s)
# [t-SNE] Iteration 700: error = 1.0132774, gradient norm = 0.0000691 (50 iterations in 1.876s)
# [t-SNE] Iteration 750: error = 1.0109520, gradient norm = 0.0000560 (50 iterations in 1.878s)
# [t-SNE] Iteration 800: error = 1.0090219, gradient norm = 0.0000515 (50 iterations in 1.879s)
# [t-SNE] Iteration 850: error = 1.0073398, gradient norm = 0.0000525 (50 iterations in 1.885s)
# [t-SNE] Iteration 900: error = 1.0060908, gradient norm = 0.0000500 (50 iterations in 1.908s)
# [t-SNE] Iteration 950: error = 1.0050354, gradient norm = 0.0000454 (50 iterations in 1.931s)
# [t-SNE] Iteration 1000: error = 1.0042840, gradient norm = 0.0000467 (50 iterations in 1.950s)
# [t-SNE] Error after 1000 iterations: 1.004284

# %% [markdown]
# ### Plot the TSNE

# %%
x = []
y = []
labels = []
topics=values_col   # DECLARE THE LABELS THAT YOU WOULD LIKE ON THE PLOT. 
num_topics = len(token_emotion[0])  # new vector called topics with actual topics or emotions used
for value in new_values:
    x.append(value[0])
    y.append(value[1])

cmap = matplotlib.cm.get_cmap('nipy_spectral')
cmapScale = int(cmap.N / num_topics)
plt.figure(figsize=(30, 30),facecolor='white')
labels = [] 
for i in range(len(x)):
    label = np.argmax(token_emotion[i])
    labels.append(label)
    plt.scatter(x[i],y[i], c=cmap(label*cmapScale),s=100)

color_legend = []
for i in range(num_topics):
    boolArr = np.array(labels) == i
    x_avg = np.median(np.array(x)[boolArr])
    y_avg = np.median(np.array(y)[boolArr])
    plt.annotate(topics[i],
                 xy=(x_avg, y_avg),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='center',
                 va='center',
                 fontsize=25,
                 bbox=dict(boxstyle="round", fc="whitesmoke",alpha=0.7))

plt.axis('off')
plt.show()
